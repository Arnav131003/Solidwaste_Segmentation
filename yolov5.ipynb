# %%
# !git clone https://github.com/ultralytics/yolov5.git
# %cd yolov5
# %pip install -r requirements.txt
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.
# /home/samantha/Desktop/Arnav/Solidwaste_segmentation/yolov5
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
import utils
display = utils.notebook_init()
# Out:
# YOLOv5 🚀 v7.0-120-g3e55763 Python-3.10.6 torch-1.12.1+cu102 CUDA:0 (NVIDIA TITAN X (Pascal), 12193MiB)
# Setup complete ✅ (16 CPUs, 15.5 GB RAM, 91.0/227.7 GB disk)

# %%
# !python3 segment/train.py --img 640 --batch 10 --epochs 100 --data solidwaste_dataset/data.yaml --weights yolov5x-seg.pt
# Out:
# segment/train: weights=yolov5x-seg.pt, cfg=, data=solidwaste_dataset/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=10, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train-seg, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, mask_ratio=4, no_overlap=False
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-120-g3e55763 Python-3.10.6 torch-1.12.1+cu102 CUDA:0 (NVIDIA TITAN X (Pascal), 12193MiB)
#
# ...

# %%
# !python3 segment/predict.py --weights yolov5x-seg.pt --data /home/samantha/Desktop/Arnav/Solidwaste_segmentation/test_1.jpeg
# Out:
# segment/predict: weights=['yolov5x-seg.pt'], source=data/images, data=/home/samantha/Desktop/Arnav/Solidwaste_segmentation/test_1.jpeg, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/predict-seg, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1, retina_masks=False
# YOLOv5 🚀 v7.0-120-g3e55763 Python-3.10.6 torch-1.12.1+cu102 CUDA:0 (NVIDIA TITAN X (Pascal), 12193MiB)
#
# Fusing layers...
# YOLOv5x-seg summary: 455 layers, 88774445 parameters, 0 gradients, 265.7 GFLOPs
# image 1/2 /home/samantha/Desktop/Arnav/Solidwaste_segmentation/yolov5/data/images/bus.jpg: 640x480 4 persons, 1 bus, 1 tie, 1 potted plant, 36.8ms
# ...
